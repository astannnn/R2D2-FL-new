# %%
import os

if not os.path.exists("/content/R2D2-FL"):
    # !git clone https://github.com/astannnn/R2D2-FL.git

# %cd /content/R2D2-FL

from config import EMNISTConfig
from main import main

config = EMNISTConfig()

config.ROUNDS = 1
config.LOCAL_EPOCHS = 1
config.NUM_CLIENTS = 2
config.CLIENT_FRACTION = 1.0

config.NOISE_RATE = 0.0
config.NOISE_TYPE = "symmetric"

config.USE_R2D2 = False
config.PROXY_SIZE = 0

main(config)

print("\nEMNIST pipeline finished successfully ✅")
