# %%
import os
import torch

REPO_URL = "https://github.com/astannnn/R2D2-FL-new.git"
REPO_DIR = "/content/R2D2-FL-new"

if not os.path.exists(REPO_DIR):
    # !git clone {REPO_URL} {REPO_DIR}
else:
    # %cd {REPO_DIR}
    # !git pull

# %cd {REPO_DIR}

from config import CIFARConfig
from main import main

config = CIFARConfig()

config.DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

config.ROUNDS = 1
config.LOCAL_EPOCHS = 1
config.NUM_CLIENTS = 2
config.CLIENT_FRACTION = 1.0

config.NOISE_RATE = 0.0
config.NOISE_TYPE = "symmetric"

config.USE_FEDPROX = False
config.USE_FEDDF = False
config.USE_R2D2 = False
config.USE_SELECTIVE_FD = False
config.USE_FEDNORO = False
config.PROXY_SIZE = 0

main(config)

print("\nCIFAR pipeline finished successfully ✅")
